# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhavsatpathy/EVA/blob/master/Session8/EVA_S8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Network Correction:
#
# In this part of the assignment - we have to run the given network to 50 epochs to acheive a base accuracy score.
#
# Then, we need to fix the basic architecture to improve on this base accuracy - without really using special convolution techniques

# %% [markdown]
# ###Importing Modules:
#
# We utilize the code snippen below to import modules to our runtime so that we can use the interfaces exposed by these modules to write and adjust our CNN. We describe only a few modules below that we have not covered in previous assignments:
#
# - **ModelCheckpoint** : This is among the many callbacks provided by Keras that we can use while training our model. We will use this to store the best model weights so that we do not loose out on them by updations performed during subsequent epochs ([Documentation](https://keras.io/callbacks/))
#
# - **ImageDataGenerator** : This module helps us perform image augmentation which is a very strong regularization measure. We can use this to apply transformations like rotation, translation, random crop etc. on out training dataset before passing them on to the network ([Documentation](https://keras.io/preprocessing/image/))
#
# - **Dropout** : This a keras layer that implements dropouts. Dropouts are another regurarization mechanism that drop certain pixel values while training the model so that our model does not overfit to the training images ([Documentation](https://keras.io/layers/core/))

# %%
from keras import backend as K
import cv2
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Loading and Pre-Processing the Data:
#
# Some details about the dataset:
#
# - Name : Cifar10
# - Number of classes : 10
# - Training set size : 50K
# - Test set size : 10K
# - Image resolution : 32x32
#
# In the code below, we :
#
# - Load the data extracted from a tar.gz file into python variables *(train_features, test_features , test_labels and train_labels)*
# - Each of the images are in shape *[3, 32, 32]* and labels are simple integers

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %% [markdown]
# ###Looking at a few examples :
#
# In the code below, we :
#
# - Decode the int labels into class names using a python list
#
# Then for each of our classes we do the following:
# - Add a subplot to the figure
# - Find the first image in the trainset with that label
# - Plot that image to the subplot
# - Set the class name as the title of the subplot

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ### Plotting model history:
#
# In the code below, we define a utility function that takes the history returned by the *fit_generator()* function and plots the record of the accuracies and losses:
#
# - Plot the train and test accuracies recorded after every epoch
# - Plot the train and test losses recorded after every epoch

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# ###Getting the accuracy:
#
# The code below defines a utility function that calculates the accuracy given:
#
# - Training Images of shape *(batch_size, height, width, num_channels)*
# - Training labels of shape *(batch_size, num_classes)*
# - Returns accuracy in percentage

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# ###Processing the data:
#
# We do the following in the code below:
#
# - Convert image matrices to float
# - Encode the labels in a One hot format

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

print(train_features.shape)
print(train_labels.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)

# %%
def get_cutout_fn(min_area_ratio, max_area_ratio):
  area_ratio = np.random.uniform(min_area_ratio, max_area_ratio)
  def cutout(X):
    
    H, W, C = X.shape
    
    img_area = H*W
    cutout_area = img_area * area_ratio
    
    
    max_aspect_ratio = max([(H*H)/cutout_area,cutout_area/(W*W)])
    min_aspect_ratio = min([(H*H)/cutout_area,cutout_area/(W*W)])
    
    aspect_ratio = np.random.uniform(min_aspect_ratio, max_aspect_ratio)
    
    cutout_width = int(np.ceil(np.sqrt(cutout_area/aspect_ratio)))
    cutout_height = int(np.ceil(np.sqrt(cutout_area*aspect_ratio)))
    
    if cutout_height == 32:
      top = 0
    else:
      top = np.random.randint(0, H - cutout_height)  
    
    if cutout_width == 32:
      left = 0
    else:
      left = np.random.randint(0, W - cutout_width)
    
    for c in range(C):
      mu = np.mean(X[top:top + cutout_height, left:left + cutout_width, c])
      X[top:top + cutout_height, left: left + cutout_width, c] = mu
      
      
    return X
    
    
  return cutout

cutout_fn = get_cutout_fn(0.1, 0.3)
plt.imshow(cutout_fn(train_features[3465]))

# %%
def gradCAM(img, model, layer_name):
  class_idx = np.argmax(model.predict(img)[0])
  
  class_output = model.output[:, class_idx]
  layer = model.get_layer(layer_name)
  
  grads = K.gradients(class_output, layer.output)[0]
  pooled_grads = K.mean(grads, axis = (0, 1, 2))
  
  iterate = K.function([model.input],[pooled_grads, layer.output[0]])
  
  pooled_grads_val, layer_output_val = iterate([img])
  
  
  for i in range(pooled_grads_val.shape[0]):
    layer_output_val[:,:,i] *= pooled_grads_val[i]
  
  heatmap = np.sum(layer_output_val, axis = 2)
  heatmap = np.maximum(heatmap, 0)
  
  heatmap /= np.max(heatmap)
  
  heatmap = cv2.resize(heatmap, (32,32))
  heatmap = np.uint8(heatmap * 255)

  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_RAINBOW)
    
  return heatmap
  
  
  
plt.imshow(gradCAM(train_features[67].reshape([-1,32,32,3]), model_co, 'conv2d_11'))

# %% [markdown]
# ###Repairing the model:
#
# We add the following to the model above to better it's performance:
#
# - Dropouts after each conv layer
# - Bottleneck layers
# - Global average pooling before softmax
# - Batch Normalization after each convolution layer
#
# The model thus obtained :
#
# - Contains 824K parameters
# - Trains to around 90 % validation accuracy

# %%
from keras.regularizers import l2

def get_model():

  # Define the model
  model = Sequential()

  model.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=(32, 32, 3))) #3
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.1))

  model.add(Convolution2D(48, 3, 3, border_mode = 'same')) #5
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.1))

  model.add(Convolution2D(64, 3, 3, border_mode = 'same')) #7
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.1))


  model.add(MaxPooling2D(pool_size=(2, 2))) #8 -- 16
  model.add(Convolution2D(32,1,1)) #8 -- 16

  model.add(Convolution2D(64, 3, 3, border_mode='same')) #12
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.1))

  model.add(Convolution2D(128, 3, 3, border_mode='same')) #16 
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.1))

  model.add(Convolution2D(256, 3, 3, border_mode='same')) #20
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.1))

  model.add(MaxPooling2D(pool_size=(2, 2))) #21 -- 8
  model.add(Convolution2D(64,1,1)) #21 -- 8

  model.add(Convolution2D(128, 3, 3, border_mode='same')) #29
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.1))

  model.add(Convolution2D(256, 3, 3, border_mode='same')) #37
  model.add(BatchNormalization())
  model.add(Activation('relu'))
  model.add(Dropout(0.1))

  model.add(Convolution2D(10,1,1))
  model.add(GlobalAveragePooling2D()) #1

  #model.add(Flatten())
  model.add(Activation('softmax'))
  return model;

# Compile the model
model_co = get_model()
model_co.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model_co.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:43: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 48)        13872
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 48)        192
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        27712
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_4 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_5 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          16448
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_8 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 10)          2570
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 10)                0
# _________________________________________________________________
# activation_9 (Activation)    (None, 10)                0
# =================================================================
# Total params: 824,026
# Trainable params: 822,074
# Non-trainable params: 1,952
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:50: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:55: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`

# %% [markdown]
# ###Training our better model:
#
# We use the following steps to train our better model:
#
# - We **normalize** the train and test images before passing them through the network
# - We **save the best** model obtained after each epoch
# - The model took almost 5 times longer to train but the validation accuracy improved from around 82% to around 90%

# %%
train_datagen = ImageDataGenerator(featurewise_center = True, 
                                   featurewise_std_normalization = True,
                                   rotation_range = 10,
                                   zoom_range = 0.10,
                                   width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   preprocessing_function = get_cutout_fn(0.1, 0.3))
test_datagen = ImageDataGenerator(featurewise_center = True, featurewise_std_normalization = True)
train_datagen.fit(train_features)
test_datagen.fit(test_features)

train_data_iter = train_datagen.flow(train_features,train_labels, batch_size = 128)
test_data_iter =  test_datagen.flow(test_features,test_labels, batch_size = 10000)

CKPT = ModelCheckpoint(filepath = 'best_model_co.hdf5', monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)


# train the model
start = time.time()
# Train the model
model_info = model_co.fit_generator(train_data_iter,
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = test_data_iter.next(), verbose=1, callbacks = [CKPT])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)

# compute test accuracy
model_co.load_weights('./best_model_co.hdf5')
test_features_n, test_labels_n = test_data_iter.next()
print ("Accuracy on test data is: %0.2f"%accuracy(test_features_n, test_labels_n, model_co))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
# Epoch 1/100
# 390/390 [==============================] - 35s 89ms/step - loss: 1.5787 - acc: 0.4203 - val_loss: 1.4592 - val_acc: 0.4976
#
# Epoch 00001: val_acc improved from -inf to 0.49760, saving model to best_model_co.hdf5
# Epoch 2/100
# 390/390 [==============================] - 32s 82ms/step - loss: 1.2706 - acc: 0.5413 - val_loss: 1.5749 - val_acc: 0.5076
#
# Epoch 00002: val_acc improved from 0.49760 to 0.50760, saving model to best_model_co.hdf5
# Epoch 3/100
# 390/390 [==============================] - 32s 82ms/step - loss: 1.1386 - acc: 0.5926 - val_loss: 0.9781 - val_acc: 0.6574
#
# Epoch 00003: val_acc improved from 0.50760 to 0.65740, saving model to best_model_co.hdf5
# Epoch 4/100
# 390/390 [==============================] - 32s 83ms/step - loss: 1.0552 - acc: 0.6237 - val_loss: 1.3942 - val_acc: 0.5799
#
# Epoch 00004: val_acc did not improve from 0.65740
# Epoch 5/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.9991 - acc: 0.6454 - val_loss: 1.2163 - val_acc: 0.6194
#
# Epoch 00005: val_acc did not improve from 0.65740
# Epoch 6/100
# 390/390 [==============================] - 32s 83ms/step - loss: 0.9450 - acc: 0.6679 - val_loss: 0.7726 - val_acc: 0.7269
#
# Epoch 00006: val_acc improved from 0.65740 to 0.72690, saving model to best_model_co.hdf5
# Epoch 7/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.9090 - acc: 0.6777 - val_loss: 0.7890 - val_acc: 0.7254
#
# Epoch 00007: val_acc did not improve from 0.72690
# Epoch 8/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.8761 - acc: 0.6906 - val_loss: 0.7935 - val_acc: 0.7435
#
# Epoch 00008: val_acc improved from 0.72690 to 0.74350, saving model to best_model_co.hdf5
# Epoch 9/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.8463 - acc: 0.7005 - val_loss: 0.8160 - val_acc: 0.7264
#
# Epoch 00009: val_acc did not improve from 0.74350
# Epoch 10/100
# 390/390 [==============================] - 32s 81ms/step - loss: 0.8206 - acc: 0.7103 - val_loss: 0.6740 - val_acc: 0.7677
#
# Epoch 00010: val_acc improved from 0.74350 to 0.76770, saving model to best_model_co.hdf5
# Epoch 11/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.8022 - acc: 0.7163 - val_loss: 0.7208 - val_acc: 0.7631
#
# Epoch 00011: val_acc did not improve from 0.76770
# Epoch 12/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.7862 - acc: 0.7218 - val_loss: 0.8265 - val_acc: 0.7352
#
# Epoch 00012: val_acc did not improve from 0.76770
# Epoch 13/100
# 390/390 [==============================] - 32s 81ms/step - loss: 0.7576 - acc: 0.7347 - val_loss: 0.6724 - val_acc: 0.7861
#
# Epoch 00013: val_acc improved from 0.76770 to 0.78610, saving model to best_model_co.hdf5
# Epoch 14/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.7431 - acc: 0.7389 - val_loss: 0.8306 - val_acc: 0.7371
#
# Epoch 00014: val_acc did not improve from 0.78610
# Epoch 15/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.7369 - acc: 0.7424 - val_loss: 0.6491 - val_acc: 0.7813
#
# Epoch 00015: val_acc did not improve from 0.78610
# Epoch 16/100
# 390/390 [==============================] - 32s 83ms/step - loss: 0.7200 - acc: 0.7460 - val_loss: 0.6880 - val_acc: 0.7806
#
# Epoch 00016: val_acc did not improve from 0.78610
# Epoch 17/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6986 - acc: 0.7564 - val_loss: 0.5771 - val_acc: 0.8052
#
# Epoch 00017: val_acc improved from 0.78610 to 0.80520, saving model to best_model_co.hdf5
# Epoch 18/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6911 - acc: 0.7584 - val_loss: 0.5268 - val_acc: 0.8201
#
# Epoch 00018: val_acc improved from 0.80520 to 0.82010, saving model to best_model_co.hdf5
# Epoch 19/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6891 - acc: 0.7556 - val_loss: 0.5881 - val_acc: 0.8020
#
# Epoch 00019: val_acc did not improve from 0.82010
# Epoch 20/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6672 - acc: 0.7646 - val_loss: 0.6149 - val_acc: 0.8063
#
# Epoch 00020: val_acc did not improve from 0.82010
# Epoch 21/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6588 - acc: 0.7673 - val_loss: 0.4968 - val_acc: 0.8341
#
# Epoch 00021: val_acc improved from 0.82010 to 0.83410, saving model to best_model_co.hdf5
# Epoch 22/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6470 - acc: 0.7727 - val_loss: 0.6163 - val_acc: 0.7914
#
# Epoch 00022: val_acc did not improve from 0.83410
# Epoch 23/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6397 - acc: 0.7733 - val_loss: 0.5489 - val_acc: 0.8143
#
# Epoch 00023: val_acc did not improve from 0.83410
# Epoch 24/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6344 - acc: 0.7790 - val_loss: 0.6003 - val_acc: 0.8027
#
# Epoch 00024: val_acc did not improve from 0.83410
# Epoch 25/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6225 - acc: 0.7833 - val_loss: 0.5713 - val_acc: 0.8172
#
# Epoch 00025: val_acc did not improve from 0.83410
# Epoch 26/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6196 - acc: 0.7820 - val_loss: 0.4969 - val_acc: 0.8321
#
# Epoch 00026: val_acc did not improve from 0.83410
# Epoch 27/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.6058 - acc: 0.7859 - val_loss: 0.4606 - val_acc: 0.8422
#
# Epoch 00027: val_acc improved from 0.83410 to 0.84220, saving model to best_model_co.hdf5
# Epoch 28/100
# 390/390 [==============================] - 32s 81ms/step - loss: 0.6052 - acc: 0.7883 - val_loss: 0.6781 - val_acc: 0.7961
#
# Epoch 00028: val_acc did not improve from 0.84220
# Epoch 29/100
# 390/390 [==============================] - 32s 81ms/step - loss: 0.5946 - acc: 0.7915 - val_loss: 0.7864 - val_acc: 0.7698
#
# Epoch 00029: val_acc did not improve from 0.84220
# Epoch 30/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.5862 - acc: 0.7919 - val_loss: 0.4231 - val_acc: 0.8612
#
# Epoch 00030: val_acc improved from 0.84220 to 0.86120, saving model to best_model_co.hdf5
# Epoch 31/100
# 390/390 [==============================] - 32s 81ms/step - loss: 0.5810 - acc: 0.7952 - val_loss: 0.6380 - val_acc: 0.8008
#
# Epoch 00031: val_acc did not improve from 0.86120
# Epoch 32/100
# 390/390 [==============================] - 32s 82ms/step - loss: 0.5783 - acc: 0.7962 - val_loss: 0.6512 - val_acc: 0.8082
#
# Epoch 00032: val_acc did not improve from 0.86120
# Epoch 33/100
# 390/390 [==============================] - 32s 81ms/step - loss: 0.5651 - acc: 0.7998 - val_loss: 0.4909 - val_acc: 0.8395
#
# Epoch 00033: val_acc did not improve from 0.86120
# Epoch 34/100
# 390/390 [==============================] - 32s 81ms/step - loss: 0.5599 - acc: 0.8042 - val_loss: 0.4985 - val_acc: 0.8394
#
# Epoch 00034: val_acc did not improve from 0.86120
# Epoch 35/100
# 390/390 [==============================] - 32s 81ms/step - loss: 0.5591 - acc: 0.8022 - val_loss: 0.4678 - val_acc: 0.8482
#
# Epoch 00035: val_acc did not improve from 0.86120
# Epoch 36/100
# 390/390 [==============================] - 31s 80ms/step - loss: 0.5542 - acc: 0.8066 - val_loss: 0.4824 - val_acc: 0.8442
#
# Epoch 00036: val_acc did not improve from 0.86120
# Epoch 37/100
# 390/390 [==============================] - 31s 80ms/step - loss: 0.5452 - acc: 0.8081 - val_loss: 0.5931 - val_acc: 0.8226
#
# Epoch 00037: val_acc did not improve from 0.86120
# Epoch 38/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5457 - acc: 0.8088 - val_loss: 0.5468 - val_acc: 0.8285
#
# Epoch 00038: val_acc did not improve from 0.86120
# Epoch 39/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5408 - acc: 0.8096 - val_loss: 0.4889 - val_acc: 0.8439
#
# Epoch 00039: val_acc did not improve from 0.86120
# Epoch 40/100
# 390/390 [==============================] - 31s 80ms/step - loss: 0.5356 - acc: 0.8131 - val_loss: 0.5804 - val_acc: 0.8206
#
# Epoch 00040: val_acc did not improve from 0.86120
# Epoch 41/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5259 - acc: 0.8158 - val_loss: 0.5387 - val_acc: 0.8303
#
# Epoch 00041: val_acc did not improve from 0.86120
# Epoch 42/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5316 - acc: 0.8132 - val_loss: 0.3946 - val_acc: 0.8725
#
# Epoch 00042: val_acc improved from 0.86120 to 0.87250, saving model to best_model_co.hdf5
# Epoch 43/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5208 - acc: 0.8158 - val_loss: 0.5095 - val_acc: 0.8383
#
# Epoch 00043: val_acc did not improve from 0.87250
# Epoch 44/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5156 - acc: 0.8180 - val_loss: 0.4541 - val_acc: 0.8505
#
# Epoch 00044: val_acc did not improve from 0.87250
# Epoch 45/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.5140 - acc: 0.8199 - val_loss: 0.5327 - val_acc: 0.8350
#
# Epoch 00045: val_acc did not improve from 0.87250
# Epoch 46/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.5084 - acc: 0.8225 - val_loss: 0.4506 - val_acc: 0.8550
#
# Epoch 00046: val_acc did not improve from 0.87250
# Epoch 47/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4998 - acc: 0.8237 - val_loss: 0.4903 - val_acc: 0.8447
#
# Epoch 00047: val_acc did not improve from 0.87250
# Epoch 48/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4979 - acc: 0.8244 - val_loss: 0.5110 - val_acc: 0.8459
#
# Epoch 00048: val_acc did not improve from 0.87250
# Epoch 49/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4959 - acc: 0.8263 - val_loss: 0.4804 - val_acc: 0.8528
#
# Epoch 00049: val_acc did not improve from 0.87250
# Epoch 50/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4869 - acc: 0.8271 - val_loss: 0.4242 - val_acc: 0.8634
#
# Epoch 00050: val_acc did not improve from 0.87250
# Epoch 51/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4868 - acc: 0.8284 - val_loss: 0.6358 - val_acc: 0.8048
#
# Epoch 00051: val_acc did not improve from 0.87250
# Epoch 52/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4867 - acc: 0.8280 - val_loss: 0.4254 - val_acc: 0.8640
#
# Epoch 00052: val_acc did not improve from 0.87250
# Epoch 53/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4803 - acc: 0.8308 - val_loss: 0.6194 - val_acc: 0.8144
#
# Epoch 00053: val_acc did not improve from 0.87250
# Epoch 54/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4789 - acc: 0.8311 - val_loss: 0.3949 - val_acc: 0.8716
#
# Epoch 00054: val_acc did not improve from 0.87250
# Epoch 55/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4786 - acc: 0.8313 - val_loss: 0.4524 - val_acc: 0.8554
#
# Epoch 00055: val_acc did not improve from 0.87250
# Epoch 56/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4736 - acc: 0.8307 - val_loss: 0.5567 - val_acc: 0.8356
#
# Epoch 00056: val_acc did not improve from 0.87250
# Epoch 57/100
# 390/390 [==============================] - 30s 78ms/step - loss: 0.4663 - acc: 0.8351 - val_loss: 0.5108 - val_acc: 0.8445
#
# Epoch 00057: val_acc did not improve from 0.87250
# Epoch 58/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4630 - acc: 0.8364 - val_loss: 0.4487 - val_acc: 0.8583
#
# Epoch 00058: val_acc did not improve from 0.87250
# Epoch 59/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4644 - acc: 0.8371 - val_loss: 0.4852 - val_acc: 0.8503
#
# Epoch 00059: val_acc did not improve from 0.87250
# Epoch 60/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4537 - acc: 0.8408 - val_loss: 0.5513 - val_acc: 0.8332
#
# Epoch 00060: val_acc did not improve from 0.87250
# Epoch 61/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4613 - acc: 0.8370 - val_loss: 0.5023 - val_acc: 0.8433
#
# Epoch 00061: val_acc did not improve from 0.87250
# Epoch 62/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4544 - acc: 0.8391 - val_loss: 0.4406 - val_acc: 0.8643
#
# Epoch 00062: val_acc did not improve from 0.87250
# Epoch 63/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4470 - acc: 0.8420 - val_loss: 0.5395 - val_acc: 0.8374
#
# Epoch 00063: val_acc did not improve from 0.87250
# Epoch 64/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4489 - acc: 0.8414 - val_loss: 0.7177 - val_acc: 0.8024
#
# Epoch 00064: val_acc did not improve from 0.87250
# Epoch 65/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4423 - acc: 0.8446 - val_loss: 0.4079 - val_acc: 0.8723
#
# Epoch 00065: val_acc did not improve from 0.87250
# Epoch 66/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4400 - acc: 0.8442 - val_loss: 0.4486 - val_acc: 0.8629
#
# Epoch 00066: val_acc did not improve from 0.87250
# Epoch 67/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4437 - acc: 0.8434 - val_loss: 0.4465 - val_acc: 0.8673
#
# Epoch 00067: val_acc did not improve from 0.87250
# Epoch 68/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4329 - acc: 0.8465 - val_loss: 0.4473 - val_acc: 0.8627
#
# Epoch 00068: val_acc did not improve from 0.87250
# Epoch 69/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4408 - acc: 0.8440 - val_loss: 0.4337 - val_acc: 0.8681
#
# Epoch 00069: val_acc did not improve from 0.87250
# Epoch 70/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4322 - acc: 0.8466 - val_loss: 0.3665 - val_acc: 0.8805
#
# Epoch 00070: val_acc improved from 0.87250 to 0.88050, saving model to best_model_co.hdf5
# Epoch 71/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4268 - acc: 0.8486 - val_loss: 0.4816 - val_acc: 0.8548
#
# Epoch 00071: val_acc did not improve from 0.88050
# Epoch 72/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4252 - acc: 0.8503 - val_loss: 0.5263 - val_acc: 0.8454
#
# Epoch 00072: val_acc did not improve from 0.88050
# Epoch 73/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4292 - acc: 0.8471 - val_loss: 0.4467 - val_acc: 0.8634
#
# Epoch 00073: val_acc did not improve from 0.88050
# Epoch 74/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4173 - acc: 0.8517 - val_loss: 0.4998 - val_acc: 0.8499
#
# Epoch 00074: val_acc did not improve from 0.88050
# Epoch 75/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4194 - acc: 0.8525 - val_loss: 0.5023 - val_acc: 0.8520
#
# Epoch 00075: val_acc did not improve from 0.88050
# Epoch 76/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4228 - acc: 0.8493 - val_loss: 0.4734 - val_acc: 0.8574
#
# Epoch 00076: val_acc did not improve from 0.88050
# Epoch 77/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4197 - acc: 0.8509 - val_loss: 0.4309 - val_acc: 0.8682
#
# Epoch 00077: val_acc did not improve from 0.88050
# Epoch 78/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4107 - acc: 0.8544 - val_loss: 0.3860 - val_acc: 0.8751
#
# Epoch 00078: val_acc did not improve from 0.88050
# Epoch 79/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4159 - acc: 0.8511 - val_loss: 0.4184 - val_acc: 0.8733
#
# Epoch 00079: val_acc did not improve from 0.88050
# Epoch 80/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4087 - acc: 0.8567 - val_loss: 0.4542 - val_acc: 0.8672
#
# Epoch 00080: val_acc did not improve from 0.88050
# Epoch 81/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4031 - acc: 0.8554 - val_loss: 0.3721 - val_acc: 0.8850
#
# Epoch 00081: val_acc improved from 0.88050 to 0.88500, saving model to best_model_co.hdf5
# Epoch 82/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4036 - acc: 0.8581 - val_loss: 0.4299 - val_acc: 0.8740
#
# Epoch 00082: val_acc did not improve from 0.88500
# Epoch 83/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4094 - acc: 0.8540 - val_loss: 0.3896 - val_acc: 0.8798
#
# Epoch 00083: val_acc did not improve from 0.88500
# Epoch 84/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.4028 - acc: 0.8565 - val_loss: 0.4623 - val_acc: 0.8641
#
# Epoch 00084: val_acc did not improve from 0.88500
# Epoch 85/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.4012 - acc: 0.8590 - val_loss: 0.3915 - val_acc: 0.8785
#
# Epoch 00085: val_acc did not improve from 0.88500
# Epoch 86/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.3997 - acc: 0.8590 - val_loss: 0.4603 - val_acc: 0.8660
#
# Epoch 00086: val_acc did not improve from 0.88500
# Epoch 87/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.3982 - acc: 0.8580 - val_loss: 0.4032 - val_acc: 0.8787
#
# Epoch 00087: val_acc did not improve from 0.88500
# Epoch 88/100
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3932 - acc: 0.8588 - val_loss: 0.4462 - val_acc: 0.8676
#
# Epoch 00088: val_acc did not improve from 0.88500
# Epoch 89/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.3967 - acc: 0.8596 - val_loss: 0.3639 - val_acc: 0.8898
#
# Epoch 00089: val_acc improved from 0.88500 to 0.88980, saving model to best_model_co.hdf5
# Epoch 90/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.3928 - acc: 0.8611 - val_loss: 0.4461 - val_acc: 0.8678
#
# Epoch 00090: val_acc did not improve from 0.88980
# Epoch 91/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.3845 - acc: 0.8645 - val_loss: 0.4537 - val_acc: 0.8733
#
# Epoch 00091: val_acc did not improve from 0.88980
# Epoch 92/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.3939 - acc: 0.8606 - val_loss: 0.4225 - val_acc: 0.8731
#
# Epoch 00092: val_acc did not improve from 0.88980
# Epoch 93/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.3798 - acc: 0.8652 - val_loss: 0.4344 - val_acc: 0.8734
#
# Epoch 00093: val_acc did not improve from 0.88980
# Epoch 94/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.3838 - acc: 0.8632 - val_loss: 0.3603 - val_acc: 0.8882
#
# Epoch 00094: val_acc did not improve from 0.88980
# Epoch 95/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.3832 - acc: 0.8634 - val_loss: 0.4194 - val_acc: 0.8709
#
# Epoch 00095: val_acc did not improve from 0.88980
# Epoch 96/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.3842 - acc: 0.8635 - val_loss: 0.4159 - val_acc: 0.8772
#
# Epoch 00096: val_acc did not improve from 0.88980
# Epoch 97/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.3802 - acc: 0.8640 - val_loss: 0.4938 - val_acc: 0.8624
#
# Epoch 00097: val_acc did not improve from 0.88980
# Epoch 98/100
# 390/390 [==============================] - 30s 78ms/step - loss: 0.3798 - acc: 0.8652 - val_loss: 0.3966 - val_acc: 0.8825
#
# Epoch 00098: val_acc did not improve from 0.88980
# Epoch 99/100
# 390/390 [==============================] - 31s 78ms/step - loss: 0.3799 - acc: 0.8631 - val_loss: 0.3689 - val_acc: 0.8854
#
# Epoch 00099: val_acc did not improve from 0.88980
# Epoch 100/100
# 390/390 [==============================] - 31s 79ms/step - loss: 0.3758 - acc: 0.8675 - val_loss: 0.4303 - val_acc: 0.8756
#
# Epoch 00100: val_acc did not improve from 0.88980
# Model took 3119.74 seconds to train
# Accuracy on test data is: 88.98

# %%
model_wco = get_model()
model_wco.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model_wco.summary()

train_datagen = ImageDataGenerator(featurewise_center = True, 
                                   featurewise_std_normalization = True,
                                   rotation_range = 10,
                                   zoom_range = 0.10,
                                   width_shift_range = 0.1,
                                   height_shift_range = 0.1
                                   )
test_datagen = ImageDataGenerator(featurewise_center = True, featurewise_std_normalization = True)
train_datagen.fit(train_features)
test_datagen.fit(test_features)

train_data_iter = train_datagen.flow(train_features,train_labels, batch_size = 128)
test_data_iter =  test_datagen.flow(test_features,test_labels, batch_size = 10000)

CKPT = ModelCheckpoint(filepath = 'best_model_wco.hdf5', monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='max', period=1)


# train the model
start = time.time()
# Train the model
model_info = model_wco.fit_generator(train_data_iter,
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = test_data_iter.next(), verbose=1, callbacks = [CKPT])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)

# compute test accuracy
model_wco.load_weights('./best_model_wco.hdf5')
test_features, test_labels = test_data_iter.next()
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model_wco))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:43: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:50: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:55: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_10 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 48)        13872
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32, 32, 48)        192
# _________________________________________________________________
# activation_11 (Activation)   (None, 32, 32, 48)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 64)        27712
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_12 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 32)        2080
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# activation_13 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_14 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 16, 256)       295168
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_15 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 8, 8, 64)          16448
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_16 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_17 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 8, 8, 10)          2570
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 10)                0
# _________________________________________________________________
# activation_18 (Activation)   (None, 10)                0
# =================================================================
# Total params: 824,026
# Trainable params: 822,074
# Non-trainable params: 1,952
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=50)`
# Epoch 1/50
# 390/390 [==============================] - 30s 78ms/step - loss: 1.3632 - acc: 0.5027 - val_loss: 1.6267 - val_acc: 0.5054
#
# Epoch 00001: val_acc improved from -inf to 0.50540, saving model to best_model_wco.hdf5
# Epoch 2/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.9607 - acc: 0.6581 - val_loss: 1.2674 - val_acc: 0.5772
#
# Epoch 00002: val_acc improved from 0.50540 to 0.57720, saving model to best_model_wco.hdf5
# Epoch 3/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.7909 - acc: 0.7214 - val_loss: 0.8913 - val_acc: 0.7005
#
# Epoch 00003: val_acc improved from 0.57720 to 0.70050, saving model to best_model_wco.hdf5
# Epoch 4/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.6969 - acc: 0.7567 - val_loss: 0.8619 - val_acc: 0.7024
#
# Epoch 00004: val_acc improved from 0.70050 to 0.70240, saving model to best_model_wco.hdf5
# Epoch 5/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.6288 - acc: 0.7814 - val_loss: 0.9444 - val_acc: 0.6962
#
# Epoch 00005: val_acc did not improve from 0.70240
# Epoch 6/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.5825 - acc: 0.7970 - val_loss: 0.6386 - val_acc: 0.7775
#
# Epoch 00006: val_acc improved from 0.70240 to 0.77750, saving model to best_model_wco.hdf5
# Epoch 7/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.5357 - acc: 0.8144 - val_loss: 0.6200 - val_acc: 0.7918
#
# Epoch 00007: val_acc improved from 0.77750 to 0.79180, saving model to best_model_wco.hdf5
# Epoch 8/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.5019 - acc: 0.8245 - val_loss: 0.8215 - val_acc: 0.7388
#
# Epoch 00008: val_acc did not improve from 0.79180
# Epoch 9/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.4735 - acc: 0.8364 - val_loss: 0.5888 - val_acc: 0.8070
#
# Epoch 00009: val_acc improved from 0.79180 to 0.80700, saving model to best_model_wco.hdf5
# Epoch 10/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.4475 - acc: 0.8449 - val_loss: 1.0342 - val_acc: 0.6869
#
# Epoch 00010: val_acc did not improve from 0.80700
# Epoch 11/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.4267 - acc: 0.8499 - val_loss: 0.6898 - val_acc: 0.7793
#
# Epoch 00011: val_acc did not improve from 0.80700
# Epoch 12/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.4096 - acc: 0.8562 - val_loss: 0.6010 - val_acc: 0.8042
#
# Epoch 00012: val_acc did not improve from 0.80700
# Epoch 13/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3854 - acc: 0.8665 - val_loss: 0.4744 - val_acc: 0.8464
#
# Epoch 00013: val_acc improved from 0.80700 to 0.84640, saving model to best_model_wco.hdf5
# Epoch 14/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3651 - acc: 0.8717 - val_loss: 0.4784 - val_acc: 0.8428
#
# Epoch 00014: val_acc did not improve from 0.84640
# Epoch 15/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3536 - acc: 0.8764 - val_loss: 0.6448 - val_acc: 0.7990
#
# Epoch 00015: val_acc did not improve from 0.84640
# Epoch 16/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3423 - acc: 0.8808 - val_loss: 0.5604 - val_acc: 0.8229
#
# Epoch 00016: val_acc did not improve from 0.84640
# Epoch 17/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3256 - acc: 0.8859 - val_loss: 0.5523 - val_acc: 0.8267
#
# Epoch 00017: val_acc did not improve from 0.84640
# Epoch 18/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3120 - acc: 0.8903 - val_loss: 0.4479 - val_acc: 0.8496
#
# Epoch 00018: val_acc improved from 0.84640 to 0.84960, saving model to best_model_wco.hdf5
# Epoch 19/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.3034 - acc: 0.8931 - val_loss: 0.5302 - val_acc: 0.8284
#
# Epoch 00019: val_acc did not improve from 0.84960
# Epoch 20/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2877 - acc: 0.8980 - val_loss: 0.6648 - val_acc: 0.7926
#
# Epoch 00020: val_acc did not improve from 0.84960
# Epoch 21/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2786 - acc: 0.9012 - val_loss: 0.5068 - val_acc: 0.8415
#
# Epoch 00021: val_acc did not improve from 0.84960
# Epoch 22/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2752 - acc: 0.9030 - val_loss: 0.5541 - val_acc: 0.8275
#
# Epoch 00022: val_acc did not improve from 0.84960
# Epoch 23/50
# 390/390 [==============================] - 27s 70ms/step - loss: 0.2675 - acc: 0.9070 - val_loss: 0.4675 - val_acc: 0.8511
#
# Epoch 00023: val_acc improved from 0.84960 to 0.85110, saving model to best_model_wco.hdf5
# Epoch 24/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2552 - acc: 0.9082 - val_loss: 0.4472 - val_acc: 0.8587
#
# Epoch 00024: val_acc improved from 0.85110 to 0.85870, saving model to best_model_wco.hdf5
# Epoch 25/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2427 - acc: 0.9139 - val_loss: 0.4609 - val_acc: 0.8539
#
# Epoch 00025: val_acc did not improve from 0.85870
# Epoch 26/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2443 - acc: 0.9133 - val_loss: 0.4283 - val_acc: 0.8627
#
# Epoch 00026: val_acc improved from 0.85870 to 0.86270, saving model to best_model_wco.hdf5
# Epoch 27/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2337 - acc: 0.9185 - val_loss: 0.5963 - val_acc: 0.8291
#
# Epoch 00027: val_acc did not improve from 0.86270
# Epoch 28/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2211 - acc: 0.9198 - val_loss: 0.4761 - val_acc: 0.8559
#
# Epoch 00028: val_acc did not improve from 0.86270
# Epoch 29/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2155 - acc: 0.9246 - val_loss: 0.4781 - val_acc: 0.8506
#
# Epoch 00029: val_acc did not improve from 0.86270
# Epoch 30/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2131 - acc: 0.9246 - val_loss: 0.4070 - val_acc: 0.8756
#
# Epoch 00030: val_acc improved from 0.86270 to 0.87560, saving model to best_model_wco.hdf5
# Epoch 31/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.2079 - acc: 0.9261 - val_loss: 0.4027 - val_acc: 0.8729
#
# Epoch 00031: val_acc did not improve from 0.87560
# Epoch 32/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1992 - acc: 0.9299 - val_loss: 0.4740 - val_acc: 0.8525
#
# Epoch 00032: val_acc did not improve from 0.87560
# Epoch 33/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1965 - acc: 0.9310 - val_loss: 0.4827 - val_acc: 0.8527
#
# Epoch 00033: val_acc did not improve from 0.87560
# Epoch 34/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1919 - acc: 0.9327 - val_loss: 0.4997 - val_acc: 0.8543
#
# Epoch 00034: val_acc did not improve from 0.87560
# Epoch 35/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1850 - acc: 0.9347 - val_loss: 0.7150 - val_acc: 0.8015
#
# Epoch 00035: val_acc did not improve from 0.87560
# Epoch 36/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1839 - acc: 0.9333 - val_loss: 0.4313 - val_acc: 0.8649
#
# Epoch 00036: val_acc did not improve from 0.87560
# Epoch 37/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1772 - acc: 0.9361 - val_loss: 0.5733 - val_acc: 0.8468
#
# Epoch 00037: val_acc did not improve from 0.87560
# Epoch 38/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1713 - acc: 0.9390 - val_loss: 0.4579 - val_acc: 0.8632
#
# Epoch 00038: val_acc did not improve from 0.87560
# Epoch 39/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1724 - acc: 0.9393 - val_loss: 0.4947 - val_acc: 0.8542
#
# Epoch 00039: val_acc did not improve from 0.87560
# Epoch 40/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1623 - acc: 0.9421 - val_loss: 0.4129 - val_acc: 0.8778
#
# Epoch 00040: val_acc improved from 0.87560 to 0.87780, saving model to best_model_wco.hdf5
# Epoch 41/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1621 - acc: 0.9434 - val_loss: 0.4273 - val_acc: 0.8718
#
# Epoch 00041: val_acc did not improve from 0.87780
# Epoch 42/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1599 - acc: 0.9421 - val_loss: 0.6014 - val_acc: 0.8409
#
# Epoch 00042: val_acc did not improve from 0.87780
# Epoch 43/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1534 - acc: 0.9454 - val_loss: 0.3749 - val_acc: 0.8819
#
# Epoch 00043: val_acc improved from 0.87780 to 0.88190, saving model to best_model_wco.hdf5
# Epoch 44/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1530 - acc: 0.9458 - val_loss: 0.4757 - val_acc: 0.8660
#
# Epoch 00044: val_acc did not improve from 0.88190
# Epoch 45/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1480 - acc: 0.9474 - val_loss: 0.4947 - val_acc: 0.8585
#
# Epoch 00045: val_acc did not improve from 0.88190
# Epoch 46/50
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1438 - acc: 0.9487 - val_loss: 0.5308 - val_acc: 0.8572
#
# Epoch 00046: val_acc did not improve from 0.88190
# Epoch 47/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1401 - acc: 0.9493 - val_loss: 0.5328 - val_acc: 0.8549
#
# Epoch 00047: val_acc did not improve from 0.88190
# Epoch 48/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1403 - acc: 0.9501 - val_loss: 0.4861 - val_acc: 0.8624
#
# Epoch 00048: val_acc did not improve from 0.88190
# Epoch 49/50
# 390/390 [==============================] - 27s 70ms/step - loss: 0.1391 - acc: 0.9501 - val_loss: 0.4422 - val_acc: 0.8757
#
# Epoch 00049: val_acc did not improve from 0.88190
# Epoch 50/50
# 390/390 [==============================] - 28s 71ms/step - loss: 0.1356 - acc: 0.9512 - val_loss: 0.5669 - val_acc: 0.8557
#
# Epoch 00050: val_acc did not improve from 0.88190
# Model took 1391.54 seconds to train
# Accuracy on test data is: 88.19

# %%
(train_features_1, train_labels_1), (test_features_1, test_labels_1) = cifar10.load_data()
test_features_scaled = test_features_1.astype('float32')/255
test_labels_1 = np_utils.to_categorical(test_labels_1, num_classes)
test_datagen.fit(test_features_scaled)
#test_data_iter =  test_datagen.flow(test_features_scaled,test_labels_1, batch_size = 10000)
test_features = test_datagen.standardize(test_features_scaled)

# %%
actuals = np.argmax(test_labels_1, axis = 1)
preds = np.argmax(model_co.predict(test_features), axis = 1)

correct_idx = [idx for idx in range(10000) if actuals[idx] == preds[idx]]
incorrect_idx = [idx for idx in range(10000) if idx not in correct_idx]

correct_plot_idx = np.random.choice(correct_idx, size = 12, replace = False)
#incorrect_plot_idx = np.random.choice(incorrect_idx, size = 12, replace = False)

fig, ax = plt.subplots(4,3, figsize = (15,15))
fig.tight_layout()
fig.suptitle("Correct Predictions")

plot_idx = 0

for i in range(4):
  for j in range(3):
    img = test_features[correct_plot_idx[plot_idx]].reshape([-1,32,32,3])
    
    unnormalized_img = test_features_1[correct_plot_idx[plot_idx]]
    
    heatmap = gradCAM(img, model_co, "conv2d_11")
    
    superimposed_img = cv2.addWeighted(unnormalized_img, 0.7, heatmap, 0.3, 0, dtype = cv2.CV_32F)/255
    
    true_class = class_names[actuals[correct_plot_idx[plot_idx]]]
    pred_class = class_names[preds[correct_plot_idx[plot_idx]]]
    plot_idx += 1
    plot_img = np.concatenate((superimposed_img, unnormalized_img/255), axis = 1)
    ax[i, j].imshow(plot_img)
    ax[i, j].set_xticklabels([])
    ax[i, j].set_yticklabels([])
    ax[i, j].set_title("Actual : {}, Pred : {}".format(true_class, pred_class))

# %%
fig, ax = plt.subplots(4,3, figsize = (15,15))
fig.tight_layout()
fig.suptitle("Gradcam without Cutout")

plot_idx = 0

for i in range(4):
  for j in range(3):
    img = test_features[correct_plot_idx[plot_idx]].reshape([-1,32,32,3])
    
    unnormalized_img = test_features_1[correct_plot_idx[plot_idx]]
    
    heatmap = gradCAM(img, model_wco, "conv2d_22")
    superimposed_img = cv2.addWeighted(unnormalized_img, 0.7, heatmap, 0.3, 0, dtype = cv2.CV_32F)/255
    
    true_class = class_names[actuals[correct_plot_idx[plot_idx]]]
    pred_class = class_names[preds[correct_plot_idx[plot_idx]]]
    plot_idx += 1
    plot_img = np.concatenate((superimposed_img, unnormalized_img/255), axis = 1)
    ax[i, j].imshow(plot_img)
    ax[i, j].set_xticklabels([])
    ax[i, j].set_yticklabels([])
    #ax[i, j].set_title("Actual : {}, Pred : {}".format(true_class, pred_class))
    
    
plt.show()
